# %%
import time

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sklearn
from riotwatcher import LolWatcher, ApiError

# %%
# API key
api_key = 'RGAPI-4d6c1518-1060-4bb8-9320-8a22e208d923'

# %%
lol_watcher = LolWatcher(api_key)

# %%
me = lol_watcher.summoner.by_name('NA1', 'Mommys Daddy')

# %%
print(me)
# Out:
# {'id': 'R3cUwNCKn0RjY4IAzSKLB51KI3NKPrgo8rW2Wvar9UO3yOE', 'accountId': '_HK7LVlJO4KFzwAZ7hcMEiwEr3SXSlKw_10oGfYOrUFpLqM', 'puuid': '3zjuMzMzT0asfwarCbHwXwLx7b754EAMH6CCRyaNGjmW4Kl1NncBYV7g9tQqQJuDBJN4yPWs3tlc6Q', 'name': 'Mommys Daddy', 'profileIconId': 5141, 'revisionDate': 1646629356000, 'summonerLevel': 194}

# %%
puuid = me['puuid']

# %%
my_ranked_stats = lol_watcher.league.by_summoner('NA1', me['id'])
print(my_ranked_stats)
# Out:
# [{'leagueId': '802c4241-295f-4a8b-b575-90f4431fe097', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'SILVER', 'rank': 'III', 'summonerId': 'R3cUwNCKn0RjY4IAzSKLB51KI3NKPrgo8rW2Wvar9UO3yOE', 'summonerName': 'Mommys Daddy', 'leaguePoints': 75, 'wins': 18, 'losses': 9, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': False}, {'leagueId': '67ad7185-adb8-4921-a031-460dff9e8c2a', 'queueType': 'RANKED_FLEX_SR', 'tier': 'SILVER', 'rank': 'III', 'summonerId': 'R3cUwNCKn0RjY4IAzSKLB51KI3NKPrgo8rW2Wvar9UO3yOE', 'summonerName': 'Mommys Daddy', 'leaguePoints': 63, 'wins': 16, 'losses': 22, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}]

# %% [markdown]
# # Questions
# * 1: Who do I play with the most?
# * 2: Who do I win with the most?

# %%
# past 20 matches
matches = lol_watcher.match.matchlist_by_puuid(region='AMERICAS', puuid=puuid)

# %%
print(matches)
# Out:
# ['NA1_4239781576', 'NA1_4239762138', 'NA1_4239710839', 'NA1_4239587721', 'NA1_4239465564', 'NA1_4239336394', 'NA1_4239302637', 'NA1_4238707491', 'NA1_4238505553', 'NA1_4238471944', 'NA1_4238428457', 'NA1_4238444581', 'NA1_4237117548', 'NA1_4235834994', 'NA1_4231948459', 'NA1_4231907677', 'NA1_4231863146', 'NA1_4224784526', 'NA1_4224686187', 'NA1_4224565065']

# %%
match_timeline = lol_watcher.match.timeline_by_match(region='AMERICAS', match_id = matches[0])

# %%
participant_col = [participant for participant in match_timeline['metadata']['participants']]

# %%
participant_col
# Out:
# ['OmyzTI5ToWbRSKwRARndrntDrIo8bcO7ED2Y5dUVedBqCQjecnY3n0IfqeGK7qwNwhErd53HinoH0Q',
#  'oM6ffNfha3W2vb0WrhhcdXt_KA8ZeOpVeJ_ODuXuu8rc4UUz0brje8qbNMAmC_G4j5ls_wQ-XrzCcg',
#  'k6HQLh3Q7bBSEVqFTdEGDbDmtCrcPHfFVpmWYEOJdBGFRLVkWHfyNX19N9RQcGEvCcDB5aeIWlVp4A',
#  '3zjuMzMzT0asfwarCbHwXwLx7b754EAMH6CCRyaNGjmW4Kl1NncBYV7g9tQqQJuDBJN4yPWs3tlc6Q',
#  'u8skmW61H6iRx_J4TjEq527RL8dH1vZJdGL-pPJqvtPdYfeSzkNmx_WS8nCEZAEEuGs1UYmQA1cYpQ',
#  'IaiAyUs_a5M0nVnjZTEFR_ufFXJph8N4y0j8rmhFMcdvcARxzgXCLq1ScJuC58q959WXZZPcd10wfg',
#  'RtYZSDl6qCFXRUrplh3qzpl-J-S7hULtPbTDGiuAjctzcGXen7kWJvuLd87K-jzkeLcE1RFzcIu7FA',
#  'e4tMBfNOcaeNYm_FwuWKm3mfmvmDFOEsUPe05TTvGJmltlFiShoTY5-6vdRzmAfjwq6mOTEBIuCbWg',
#  'm34RR6MUwdN69qnOYr_YpNRmA5YBDG741oVYsxleyiR00Z2nmfiLXYXuYWKV7inmwFzfIAYyZ1bgEA',
#  'HrFyo4Wu1bqKyX7Ey0KS4mIA3eFrlWW6Bxnp6puLKLQrI2WJ7HlqiPRaLDLQpmI4WA-A681EaNc2Sw']

# %%
match_id_col = match_timeline['metadata']['matchId']

# %%
match_id_col
# Out:
# 'NA1_4239781576'

# %%
match_timeline.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
match_timeline['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'NA1_4239781576',
#  'participants': ['OmyzTI5ToWbRSKwRARndrntDrIo8bcO7ED2Y5dUVedBqCQjecnY3n0IfqeGK7qwNwhErd53HinoH0Q',
#   'oM6ffNfha3W2vb0WrhhcdXt_KA8ZeOpVeJ_ODuXuu8rc4UUz0brje8qbNMAmC_G4j5ls_wQ-XrzCcg',
#   'k6HQLh3Q7bBSEVqFTdEGDbDmtCrcPHfFVpmWYEOJdBGFRLVkWHfyNX19N9RQcGEvCcDB5aeIWlVp4A',
#   '3zjuMzMzT0asfwarCbHwXwLx7b754EAMH6CCRyaNGjmW4Kl1NncBYV7g9tQqQJuDBJN4yPWs3tlc6Q',
#   'u8skmW61H6iRx_J4TjEq527RL8dH1vZJdGL-pPJqvtPdYfeSzkNmx_WS8nCEZAEEuGs1UYmQA1cYpQ',
#   'IaiAyUs_a5M0nVnjZTEFR_ufFXJph8N4y0j8rmhFMcdvcARxzgXCLq1ScJuC58q959WXZZPcd10wfg',
#   'RtYZSDl6qCFXRUrplh3qzpl-J-S7hULtPbTDGiuAjctzcGXen7kWJvuLd87K-jzkeLcE1RFzcIu7FA',
#   'e4tMBfNOcaeNYm_FwuWKm3mfmvmDFOEsUPe05TTvGJmltlFiShoTY5-6vdRzmAfjwq6mOTEBIuCbWg',
#   'm34RR6MUwdN69qnOYr_YpNRmA5YBDG741oVYsxleyiR00Z2nmfiLXYXuYWKV7inmwFzfIAYyZ1bgEA',
#   'HrFyo4Wu1bqKyX7Ey0KS4mIA3eFrlWW6Bxnp6puLKLQrI2WJ7HlqiPRaLDLQpmI4WA-A681EaNc2Sw']}

# %%
res = lol_watcher.match.timeline_by_match(region='AMERICAS', match_id = matches[0])

# %%
df_1 = pd.DataFrame()

# %%
df_1.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# who have i played with the most over the last 20 matches?
df = pd.DataFrame()

for match in matches:
    # get match timeline info
    timeline_res = lol_watcher.match.timeline_by_match(region='AMERICAS', match_id = match)
    # get participants
    df['participants'] = [participant for participant in timeline_res['metadata']['participants']]
    # get match_id
    df['matchId'] = timeline_res['metadata']['matchId']
    
    # append match timeline info to dataframe
    # df.append(
    
    time.sleep(10)
    

# for match in matches:
#     match_timelines = lol_watcher.match.timeline_by_match(region='AMERICAS', match_id = match)
#     participant = match_timelines['metadata']['participants']

# %%
df.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26664/942532428.py in <module>
# ----> 1 df.len()
#
# ~\miniconda3\envs\league-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
# check out match_info
match_timeline['info']['frames'][0]['participantFrames']
# Out:
# {'1': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 34,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 580,
#    'healthMax': 580,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 335,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 500,
#    'powerMax': 500,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
# ...

# %% [markdown]
# # Participants

# %%
# who are the participants in the above metadata?
# lets make a list of participants
participants_ls = [id for id in match_timeline['metadata']['participants']]

# %%
# now lets find data for each of these participants
names_ls = []
for val in participants_ls:
    participant_name = lol_watcher.summoner.by_puuid(region = 'NA1', encrypted_puuid=val)
    names_ls.append(participant_name)
    
names_ls
# Out:
# [{'id': 'JS1OX3ujpPpdDfkGXfTCs2IUK7om9jl-G4Oeoc-yvhcWvlQ',
#   'accountId': 'fRFpBTCLHh5f4bDbwFiJTvREXIFmc3-LW_0_dmtKVZtoLlM',
#   'puuid': 'OmyzTI5ToWbRSKwRARndrntDrIo8bcO7ED2Y5dUVedBqCQjecnY3n0IfqeGK7qwNwhErd53HinoH0Q',
#   'name': 'GentleTouchStin',
#   'profileIconId': 2095,
#   'revisionDate': 1646811662000,
#   'summonerLevel': 303},
#  {'id': 'ivUmQ8dIQoGo4eZmZ6k50vlqBzU1SjVnQ0loWavexxyg5ls',
#   'accountId': 'KpxPGUi_CzjvRcUR0mcbmmIR9X_hX6nm2PCXDhO6kSdDoQE',
#   'puuid': 'oM6ffNfha3W2vb0WrhhcdXt_KA8ZeOpVeJ_ODuXuu8rc4UUz0brje8qbNMAmC_G4j5ls_wQ-XrzCcg',
#   'name': 'Jman2095',
#   'profileIconId': 4568,
#   'revisionDate': 1646785035000,
#   'summonerLevel': 256},
#  {'id': 'ZyZcwiE31wd8em1BOlHJZ1TsX0Wy-WR8usG6g7mGNtrNvWY',
#   'accountId': 'CQFtu3W8rJPHriMhWzf2JIZ_u8i0BIm3vWbsmnz7vcyKcLE',
#   'puuid': 'k6HQLh3Q7bBSEVqFTdEGDbDmtCrcPHfFVpmWYEOJdBGFRLVkWHfyNX19N9RQcGEvCcDB5aeIWlVp4A',
#   'name': 'Cannøn',
#   'profileIconId': 5030,
#   'revisionDate': 1646794306000,
# ...
